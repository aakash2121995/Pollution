# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
from aakashLib import *
import glob
# %matplotlib inline
# Out:
# /usr/local/lib64/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
csv = pd.read_csv("CombinedData.tsv",sep='\t',parse_dates=["Time"])

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54598 entries, 0 to 54597
# Columns: 211 entries, Time to Civil Lines/PM2.5(Dust (PM2.5) )
# dtypes: datetime64[ns](1), float64(210)
# memory usage: 87.9 MB

# %%
# csv.to_csv("CombinedData.tsv",sep='\t',index=False)`

# %%
# data=""
# with open("CombinedData.tsv","r") as f:
#     data = f.read()

# %%
# data = data.replace(",","")

# %%
pmcols = []
for col in csv.columns:
    if col.find("PM10") >=0 or col.find("RSPM") >=0:
        print col
        pmcols.append(col)
# Out:
# R K Puram/PM10(PM10)
# Anand Vihar/PM10(PM10)
# ITO/PM10(PM10)
# MOBILE VAN/PM10(DUST)
# IHBAS/PM10(RSPM)
# IGI Airport/PM10(RPM)
# Punjabi Bagh/PM10(PM10)
# Dwarka/PM 10(RSPM)
# Mandir Marg/PM10(PM10)
# Civil Lines/PM10(RPM)

# %%
### print(csv.ix["2015":"2018"].shape)
#2017
# ('R K Puram/PM10(PM10)', 367) winner
# ('Anand Vihar/PM2.5(PM2.5)', 256) winner
# ('Anand Vihar/PM10(PM10)', 242) winner
# ('Shadipur/PM 2.5(PM2.5)', 354)
# ('ITO/PM2.5(PM2.5)', 401)
# ('ITO/PM10(PM10)', 385)
# ('IHBAS/PM 2.5(PM2.5)', 436)
# ('Sirifort/PM2.5(PM2.5)', 400)
# ('Punjabi Bagh/PM2.5(PM2.5)', 361)
# ('Punjabi Bagh/PM10(PM10)', 358) winner
# ('Mandir Marg/PM2.5(PM2.5)', 422)
# ('Mandir Marg/PM10(PM10)', 393)
# ('DTU/PM2.5(PM2.5)', 270)
#('Dwarka/PM 2.5(PM2.5)', 656)

#2016
# ('R K Puram/PM2.5(PM2.5)', 1492)
# ('R K Puram/PM10(PM10)', 975) winner
# ('Anand Vihar/PM2.5(PM2.5)', 1649)
# ('Anand Vihar/PM10(PM10)', 1740)
# ('Shadipur/PM 2.5(PM2.5)', 1610)

# ('Punjabi Bagh/PM2.5(PM2.5)', 1091) winner
# ('Punjabi Bagh/PM10(PM10)', 1125)   winner

# ('Dwarka/PM 2.5(PM2.5)', 1891)

#('IHBAS/PM 2.5(PM2.5)', 3284)

#2015
# ('R K Puram/PM2.5(PM2.5)', 3125) winner
# ('R K Puram/PM10(PM10)', 3051) winner
# ('Anand Vihar/PM2.5(PM2.5)', 3179) winner
# ('Anand Vihar/PM10(PM10)', 3371)winner
# ('Shadipur/PM 2.5(PM2.5)', 2282)  winner

# ('Punjabi Bagh/PM2.5(PM2.5)', 3317) winner
# ('Punjabi Bagh/PM10(PM10)', 3264) winner

# ('Dwarka/PM 2.5(PM2.5)', 3709) winner
# ('Mandir Marg/PM2.5(PM2.5)', 3351) winner
# ('Mandir Marg/PM10(PM10)', 3383) winner

#('IHBAS/PM 2.5(PM2.5)', 4560)


#2014
# ('IHBAS/PM10(RSPM)', 1142)
# ('IHBAS/PM 2.5(PM2.5)', 689)

# ('IGI Airport/PM2.5(Dust (PM2.5))', 3752)

# ('Dwarka/PM 10(RSPM)', 1326)

# ('Civil Lines/PM2.5(Dust (PM2.5) )', 2259)

#2015-2017
# ('R K Puram/PM10(PM10)', 4393)
# ('Shadipur/PM 2.5(PM2.5)', 4246)
# ('Punjabi Bagh/PM2.5(PM2.5)', 4769)
# ('Punjabi Bagh/PM10(PM10)', 4747)

#2014-2017
# ('R K Puram/PM2.5(PM2.5)', 14127)
# ('R K Puram/PM10(PM10)', 13153)
# ('Anand Vihar/PM2.5(PM2.5)', 13844)
# ('Anand Vihar/PM10(PM10)', 14113)
# ('Shadipur/PM 2.5(PM2.5)', 13006)
# ('IHBAS/PM 2.5(PM2.5)', 8969)      winner
# ('Punjabi Bagh/PM2.5(PM2.5)', 13529)
# ('Punjabi Bagh/PM10(PM10)', 13507)
# ('Dwarka/PM 2.5(PM2.5)', 15016)
# ('Mandir Marg/PM2.5(PM2.5)', 15463)
# ('Mandir Marg/PM10(PM10)', 15319)

# ('Civil Lines/PM2.5(Dust (PM2.5) )', 17964)

# 2011-2014

#all data
#pm2.5 ->IHBAS


#pm10
#2017
# ('R K Puram/PM10(PM10)', 367)
# ('Anand Vihar/PM10(PM10)', 242)
# ('ITO/PM10(PM10)', 385)
# ('Punjabi Bagh/PM10(PM10)', 358)

#2016
# ('R K Puram/PM10(PM10)', 975)
# ('Anand Vihar/PM10(PM10)', 1740)
# ('Punjabi Bagh/PM10(PM10)', 1125)
# ('Mandir Marg/PM10(PM10)', 2783)

#2015
# ('R K Puram/PM10(PM10)', 3051)
# ('Anand Vihar/PM10(PM10)', 3371)
# ('IGI Airport/PM10(RPM)', 5419)
# ('Punjabi Bagh/PM10(PM10)', 3264)
# ('Mandir Marg/PM10(PM10)', 3383)
# ('Civil Lines/PM10(RPM)', 4960)

#2014
# ('IHBAS/PM10(RSPM)', 1142)
# ('Dwarka/PM 10(RSPM)', 1326)
# ('Civil Lines/PM10(RPM)', 4314

#2013
# ('IHBAS/PM10(RSPM)', 1148)
# ('IGI Airport/PM10(RPM)', 3354)
# ('Dwarka/PM 10(RSPM)', 1160)
# ('Civil Lines/PM10(RPM)', 3513)

#2012

# ('IHBAS/PM10(RSPM)', 2417)
# ('IGI Airport/PM10(RPM)', 1148)
# ('Dwarka/PM 10(RSPM)', 2004)
# ('Civil Lines/PM10(RPM)', 2548)

#2011

# ('IHBAS/PM10(RSPM)', 946)
# ('IGI Airport/PM10(RPM)', 1686)

# ('Dwarka/PM 10(RSPM)', 697)

# ('Civil Lines/PM10(RPM)', 2519)





plotMissingVals(csv)
# Out:
# ('R K Puram/Wind Speed (WS)', 28602)
# ('R K Puram/Nitrogen Dioxide(NO2)', 30245)
# ('R K Puram/Wind Direction(WD)', 28602)
# ('R K Puram/Solar Radiation(SR)', 39053)
# ('R K Puram/Ammonia(NH3)', 29263)
# ('R K Puram/Temperature(AT)', 39053)
# ('R K Puram/Oxides of Nitrogen(NOx)', 29008)
# ('R K Puram/Relative Humidity(RH)', 28602)
# ('R K Puram/Carbon Monoxide(CO)', 29749)
# ('R K Puram/P Xylene(PXY)', 39759)
# ('R K Puram/Sulfur Dioxide(SO2)', 30009)
# ('R K Puram/PM2.5(PM2.5)', 40406)
# ('R K Puram/Toluene(TOL)', 42880)
# ('R K Puram/Nitric Oxide(NO)', 30680)
# ('R K Puram/Benzene(BEN)', 39564)
# ('R K Puram/Ozone(O3)', 39598)
# ('R K Puram/PM10(PM10)', 39432)
# ('R K Puram/Bar Pressure(BP)', 39053)
# ('R K Puram/Vertical Wind Speed(VWS)', 39183)
# ('Anand Vihar/Nitrogen Dioxide(NO2)', 36200)
# ('Anand Vihar/Ambient Temperature(AT)', 40074)
# ('Anand Vihar/Wind Direction(WD)', 40045)
# ('Anand Vihar/Solar Radiation(SR)', 40073)
# ('Anand Vihar/Ammonia(NH3)', 36162)
# ...

# %%
plotMissingVals(csv.ix["2016-10":"2018"][pmcols])
# Out:
# ('R K Puram/PM2.5(PM2.5)', 1114)
# ('R K Puram/PM10(PM10)', 481)
# ('Anand Vihar/PM2.5(PM2.5)', 347)
# ('Anand Vihar/PM10(PM10)', 367)
# ('Shadipur/PM 2.5(PM2.5)', 689)
# ('ITO/PM2.5(PM2.5)', 1582)
# ('ITO/PM10(PM10)', 1566)
# ('MOBILE VAN/PM10(DUST)', 4278)
# ('IHBAS/PM10(RSPM)', 4278)
# ('IHBAS/PM 2.5(PM2.5)', 832)
# ('IGI Airport/PM10(RPM)', 4278)
# ('IGI Airport/PM2.5(Dust (PM2.5))', 4278)
# ('Sirifort/PM2.5(PM2.5)', 1581)
# ('Punjabi Bagh/PM2.5(PM2.5)', 517)
# ('Punjabi Bagh/PM10(PM10)', 580)
# ('Dwarka/PM 10(RSPM)', 4278)
# ('Dwarka/PM 2.5(PM2.5)', 990)
# ('Mandir Marg/PM2.5(PM2.5)', 732)
# ('Mandir Marg/PM10(PM10)', 676)
# ('DTU/PM2.5(PM2.5)', 1594)
# ('Civil Lines/PM10(RPM)', 4278)
# ('Civil Lines/PM2.5(Dust (PM2.5) )', 4278)
# {}

# %%
# csv = csv.drop('Unnamed: 0',axis=1)
csv['year'] = csv["Time"].dt.year

# %%
for col in csv.columns[1:]:
    
#     if col.find("PM2.5") <0 and col.find("PM10") <0:
#         continue
    print(col)
    for year in range(2011,2018):
        df = csv[csv.year == year]
        missing = df[col].isnull().sum() 
        print("\t{0}:{1}".format(year,missing))
# Out:
# (AT)
# 	2011:8088
# 	2012:8170
# 	2013:8400
# 	2014:8133
# 	2015:3087
# 	2016:1057
# 	2017:5
# (BEN)
# 	2011:8088
# 	2012:5012
# 	2013:6808
# 	2014:8133
# 	2015:4575
# 	2016:2856
# 	2017:162
# (BP)
# 	2011:8088
# 	2012:8170
# 	2013:8400
# 	2014:8133
# 	2015:3087
# 	2016:1120
# 	2017:6
# (CH4)
# 	2011:1194
# 	2012:3255
# 	2013:928
# 	2014:831
# 	2015:4092
# 	2016:2567
# 	2017:370
# (CO)
# 	2011:493
# 	2012:991
# 	2013:687
# 	2014:152
# 	2015:3941
# 	2016:2538
# 	2017:349
# (NH3)
# 	2011:2908
# 	2012:3068
# 	2013:1668
# 	2014:416
# 	2015:182
# 	2016:1370
# 	2017:374
# (NMHC)
# 	2011:1086
# 	2012:3156
# 	2013:674
# 	2014:558
# 	2015:4041
# 	2016:2406
# 	2017:406
# (NO)
# 	2011:2084
# 	2012:3367
# 	2013:598
# 	2014:369
# 	2015:193
# 	2016:1156
# 	2017:409
# (NO2)
# 	2011:1671
# 	2012:2461
# 	2013:360
# 	2014:344
# 	2015:1234
# 	2016:5023
# 	2017:373
# (NOx)
# 	2011:1688
# 	2012:2702
# 	2013:809
# 	2014:1930
# 	2015:188
# 	2016:1281
# 	2017:371
# (O3)
# 	2011:8088
# 	2012:5497
# ...

# %%
csv.to_csv("lol.tsv",sep='\t')

# %%
cols = []
for col in csv.columns:
if col.find("R K") >=0 or  col.find("Siri") >=0:
    cols.append(col)
drawCorr(csv[cols])
# Out:
# /home/aakash/anaconda3/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
csv["year"]
# Out:
# 0        2011
# 1        2011
# 2        2011
# 3        2011
# 4        2011
# 5        2011
# 6        2011
# 7        2011
# 8        2011
# 9        2011
# 10       2011
# 11       2011
# 12       2011
# 13       2011
# 14       2011
# 15       2011
# 16       2011
# 17       2011
# 18       2011
# 19       2011
# 20       2011
# 21       2011
# 22       2011
# 23       2011
# 24       2011
# 25       2011
# 26       2011
# 27       2011
# 28       2011
# 29       2011
#          ...
# 50143    2017
# 50144    2017
# 50145    2017
# 50146    2017
# 50147    2017
# 50148    2017
# 50149    2017
# 50150    2017
# 50151    2017
# 50152    2017
# 50153    2017
# 50154    2017
# 50155    2017
# 50156    2017
# 50157    2017
# 50158    2017
# 50159    2017
# 50160    2017
# 50161    2017
# 50162    2017
# 50163    2017
# 50164    2017
# 50165    2017
# 50166    2017
# 50167    2017
# 50168    2017
# 50169    2017
# 50170    2017
# 50171    2017
# 50172    2017
# ...
